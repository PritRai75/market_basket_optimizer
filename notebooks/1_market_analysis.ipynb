# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
sys.path.append("..")

# %%
from src.analyzer import MarketBasketAnalyzer
from src.visualization import plot_correlation_heatmap, plot_returns_distribution

# %%
analyzer = MarketBasketAnalyzer()

tickers = ["WMT", "TGT", "COST", "KR", "AAPL"]
data = analyzer.fetch_stock_data(tickers)

correlations = analyzer.calculate_correlations()

plot_correlation_heatmap(correlations)

returns = pd.DataFrame()
for ticker, data in analyzer.stock_data.items():
    returns[ticker] = data["Close"].pct_change()
plot_returns_distribution(returns)
